# %% [markdown]
# # Mobile Price Classification using SKlearn Custom Script in Sagemaker

# %%
import sagemaker
from sklearn.model_selection import train_test_split
import boto3
import pandas as pd

sm_boto3 = boto3.client("sagemaker")
sess = sagemaker.Session()
region = sess.boto_session.region_name
bucket = 'mobbucketsager'
print("Using bucket" + bucket)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:6                                                                                    │
# │                                                                                                  │
# │    3 import boto3                                                                                │
# │    4 import pandas as pd                                                                         │
# │    5                                                                                             │
# │ ❱  6 sm_boto3 = boto3.client("sagemaker")                                                        │
# │    7 sess = sagemaker.Session()                                                                  │
# │    8 region = sess.boto_session.region_name                                                      │
# │    9 bucket = 'mobbucketsager'                                                                   │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\boto3\__init__.py:92 in client            │
# │                                                                                                  │
# │    89 │                                                                                          │
# │    90 │   See :py:meth:`boto3.session.Session.client`.                                           │
# │    91 │   """                                                                                    │
# │ ❱  92 │   return _get_default_session().client(*args, **kwargs)                                  │
# │    93                                                                                            │
# │    94                                                                                            │
# │    95 def resource(*args, **kwargs):                                                             │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\boto3\session.py:322 in client            │
# │                                                                                                  │
# │   319 │   │   :return: Service client instance                                                   │
# │   320 │   │                                                                                      │
# │   321 │   │   """                                                                                │
# │ ❱ 322 │   │   return self._session.create_client(                                                │
# │   323 │   │   │   service_name,                                                                  │
# │   324 │   │   │   region_name=region_name,                                                       │
# │   325 │   │   │   api_version=api_version,                                                       │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\context.py:124 in wrapper        │
# │                                                                                                  │
# │   121 │   │   │   with start_as_current_context():                                               │
# │   122 │   │   │   │   if hook:                                                                   │
# │   123 │   │   │   │   │   hook()                                                                 │
# │ ❱ 124 │   │   │   │   return func(*args, **kwargs)                                               │
# │   125 │   │                                                                                      │
# │   126 │   │   return wrapper                                                                     │
# │   127                                                                                            │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\session.py:1019 in create_client │
# │                                                                                                  │
# │   1016 │   │   │   config_store,                                                                 │
# │   1017 │   │   │   user_agent_creator=user_agent_creator,                                        │
# │   1018 │   │   )                                                                                 │
# │ ❱ 1019 │   │   client = client_creator.create_client(                                            │
# │   1020 │   │   │   service_name=service_name,                                                    │
# │   1021 │   │   │   region_name=region_name,                                                      │
# │   1022 │   │   │   is_secure=use_ssl,                                                            │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\client.py:166 in create_client   │
# │                                                                                                  │
# │    163 │   │   │   config_store=self._config_store,                                              │
# │    164 │   │   │   service_signature_version=service_signature_version,                          │
# │    165 │   │   )                                                                                 │
# │ ❱  166 │   │   client_args = self._get_client_args(                                              │
# │    167 │   │   │   service_model,                                                                │
# │    168 │   │   │   region_name,                                                                  │
# │    169 │   │   │   is_secure,                                                                    │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\client.py:525 in                 │
# │ _get_client_args                                                                                 │
# │                                                                                                  │
# │    522 │   │   │   config_store=self._config_store,                                              │
# │    523 │   │   │   user_agent_creator=self._user_agent_creator,                                  │
# │    524 │   │   )                                                                                 │
# │ ❱  525 │   │   return args_creator.get_client_args(                                              │
# │    526 │   │   │   service_model,                                                                │
# │    527 │   │   │   region_name,                                                                  │
# │    528 │   │   │   is_secure,                                                                    │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\args.py:125 in get_client_args   │
# │                                                                                                  │
# │   122 │   │   endpoints_ruleset_data=None,                                                       │
# │   123 │   │   partition_data=None,                                                               │
# │   124 │   ):                                                                                     │
# │ ❱ 125 │   │   final_args = self.compute_client_args(                                             │
# │   126 │   │   │   service_model,                                                                 │
# │   127 │   │   │   client_config,                                                                 │
# │   128 │   │   │   endpoint_bridge,                                                               │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\args.py:249 in                   │
# │ compute_client_args                                                                              │
# │                                                                                                  │
# │   246 │   │   if configured_endpoint_url is not None:                                            │
# │   247 │   │   │   register_feature_id('ENDPOINT_OVERRIDE')                                       │
# │   248 │   │                                                                                      │
# │ ❱ 249 │   │   endpoint_config = self._compute_endpoint_config(                                   │
# │   250 │   │   │   service_name=service_name,                                                     │
# │   251 │   │   │   region_name=region_name,                                                       │
# │   252 │   │   │   endpoint_url=configured_endpoint_url,                                          │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\args.py:432 in                   │
# │ _compute_endpoint_config                                                                         │
# │                                                                                                  │
# │   429 │   │   │   )                                                                              │
# │   430 │   │   if service_name == 'sts':                                                          │
# │   431 │   │   │   return self._compute_sts_endpoint_config(**resolve_endpoint_kwargs)            │
# │ ❱ 432 │   │   return self._resolve_endpoint(**resolve_endpoint_kwargs)                           │
# │   433 │                                                                                          │
# │   434 │   def _compute_s3_endpoint_config(                                                       │
# │   435 │   │   self, s3_config, **resolve_endpoint_kwargs                                         │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\args.py:537 in _resolve_endpoint │
# │                                                                                                  │
# │   534 │   │   is_secure,                                                                         │
# │   535 │   │   endpoint_bridge,                                                                   │
# │   536 │   ):                                                                                     │
# │ ❱ 537 │   │   return endpoint_bridge.resolve(                                                    │
# │   538 │   │   │   service_name, region_name, endpoint_url, is_secure                             │
# │   539 │   │   )                                                                                  │
# │   540                                                                                            │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\client.py:630 in resolve         │
# │                                                                                                  │
# │    627 │   │   use_fips_endpoint = self._resolve_endpoint_variant_config_var(                    │
# │    628 │   │   │   'use_fips_endpoint'                                                           │
# │    629 │   │   )                                                                                 │
# │ ❱  630 │   │   resolved = self.endpoint_resolver.construct_endpoint(                             │
# │    631 │   │   │   service_name,                                                                 │
# │    632 │   │   │   region_name,                                                                  │
# │    633 │   │   │   use_dualstack_endpoint=use_dualstack_endpoint,                                │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\regions.py:232 in                │
# │ construct_endpoint                                                                               │
# │                                                                                                  │
# │   229 │   │   │   │   in self._UNSUPPORTED_DUALSTACK_PARTITIONS                                  │
# │   230 │   │   │   ):                                                                             │
# │   231 │   │   │   │   continue                                                                   │
# │ ❱ 232 │   │   │   result = self._endpoint_for_partition(                                         │
# │   233 │   │   │   │   partition,                                                                 │
# │   234 │   │   │   │   service_name,                                                              │
# │   235 │   │   │   │   region_name,                                                               │
# │                                                                                                  │
# │ d:\Coding\RA pro\AWS SageMaker\myenv\lib\site-packages\botocore\regions.py:280 in                │
# │ _endpoint_for_partition                                                                          │
# │                                                                                                  │
# │   277 │   │   │   if 'partitionEndpoint' in service_data:                                        │
# │   278 │   │   │   │   region_name = service_data['partitionEndpoint']                            │
# │   279 │   │   │   else:                                                                          │
# │ ❱ 280 │   │   │   │   raise NoRegionError()                                                      │
# │   281 │   │                                                                                      │
# │   282 │   │   resolve_kwargs = {                                                                 │
# │   283 │   │   │   'partition': partition,                                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NoRegionError: You must specify a region.
